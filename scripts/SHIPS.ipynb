# %%
import datetime
import numpy as np
import os
import pandas as pd
import requests
import time
import xarray as xr

# %% [markdown]
# ### SHIPS documentation
# Reference: https://rammb-data.cira.colostate.edu/ships/data/ships_predictor_file.pdf

# %%
def adjust_SHIPS(TMP: pd.DataFrame) -> pd.DataFrame:

    ''' Modify raw SHIPS data for datetime formatting and units. '''
    
    # Set data types to custom fields
    TMP = TMP.astype({'hour': 'int32', 'max_wind': 'int32', 'center_lat': 'float', 'center_lon': 'float', 'min_slp': 'int32'})
    # Convert integers in 'date' to full datetimes
    TMP['time'] = TMP['time'].apply(lambda s: datetime.datetime.strptime(s, '%y%m%d')) + pd.to_timedelta(TMP['hour'], unit='h')
    TMP = TMP.drop(columns=['hour'])
    # Convert wind from knots to meters per second
    for field_name in ['max_wind', 'SHRD']:
        TMP[field_name] = TMP[field_name] * 0.514444
    # Add season to DataFrame for compatibility with IBTrACS, see conditional logic below:
    # "Season (year) that the storm began. Due to how the Southern Hemisphere defines a season, 
    # storms after July 1 are classified with the following year."
    TMP['season'] = TMP.apply(lambda x: x['time'].year if x['time'].month < 7 else x['time'].year, axis=1)

    return TMP

# %%
def load_SHIPS() -> pd.DataFrame:

    ''' 
    Method to load SHIPS data from local text file. 
    
    Text file obtained from: https://rammb-data.cira.colostate.edu/ships/data/AL/lsdiaga_1982_2022_sat_ts_5day.txt.
    '''

    # Define pathname to pull data from
    pathname = '/scratch/gpfs/GEOCLIM/gr7610/tiger3/reference/datasets/SHIPS/lsdiaga_1982_2022_sat_ts_5day.txt'
    # List of variable names of interest (only including SHRD - or vertical wind shear from 850 to 200 hPa - for now)
    varnames = ['SHRD']
    # Container for SHIPS data pertaining to `varnames`
    container = []
    
    # Placeholder for iterand storm ID name, is None before a storm ID is found
    storm_ID = None
    with open(pathname, 'r') as file:
        # Iterate over all lines in SHIPS text file
        for line_number, line in enumerate(file):
            # Strip the data
            line_entry = line.strip().split()
            
            # Capture the storm characteristics if 'HEAD' is the last index
            if line_entry[-1] == 'HEAD': 
                date, hour, day, lat, lon, min_SLP, storm_ID = line_entry[1:-1]
    
            # Only grab line if the last entry/column is in the list of specified varnames
            if line_entry[-1] in varnames:
                # Scrape zeroth-index, which is assumed to correspond to the zeroth-hour 
                # (hence the "ZH" designator, and is an approximation of observations)
                # Divide by 10 to convert to proper value (reference: https://rammb-data.cira.colostate.edu/ships/data/ships_predictor_file.pdf)
                property_ZH = int(line_entry[0]) / 10
                # Generate entry-specific dictionary to append to container for future concatenation
                entry = {'time': date, 
                         'hour': hour, 
                         'max_wind': day, 
                         'center_lat': lat, 
                         'center_lon': lon, 
                         'min_slp': min_SLP, 
                         'storm_id': storm_ID, 
                         line_entry[-1]: property_ZH}
                container.append(entry)

    # Load into Pandas DataFrame
    data = pd.DataFrame(container) 

    return data

# %%
def merge_IBTrACS_SHIPS_TC(SHIPS_TC: pd.DataFrame,
                           dataset_IBTrACS: xr.Dataset,
                           diagnostic: bool=True):

    ''' Function to merge IBTrACS and SHIPS data for a given TC. '''

    IBTrACS_TCs = [] # container list for the output TC

    # Filter the IBTrACS dataset by the iterand season to minimize data processing
    dataset_IBTrACS = dataset_IBTrACS.where(dataset_IBTrACS['season'] == SHIPS_TC['season'].min(), drop=True)

    # Iterate over all TCs that are left
    for index in range(len(dataset_IBTrACS.storm)):
        # Get the iterand TC
        IBTrACS_TC = dataset_IBTrACS.isel(storm=index)
        original_axis_length = len(IBTrACS_TC['date_time'])
        # Get indices with valid timestamps
        indices = np.where(~np.isnan(IBTrACS_TC['time']))[0]
        IBTrACS_TC = IBTrACS_TC.isel(date_time=indices)
        
        # Round to nearest hour
        IBTrACS_TC['time'] = IBTrACS_TC['time'].dt.round('h')

        if diagnostic:
            print(f'Iterand season: {IBTrACS_TC['season'].min()}, IBTrACS timestamp extent: {IBTrACS_TC.time.min().dt.round('h'), IBTrACS_TC.time.max().dt.round('h')}')
            print(f"{'#'*128}")

        # Filter 1: time check
        # Iterand IBTrACS timestamps must be greater than the referenced SHIPS TC
        if IBTrACS_TC.time.min() <= SHIPS_TC['time'].min() and IBTrACS_TC.time.max() >= SHIPS_TC['time'].max():
            # Filters 2 and 3 (filter in parallel)
            # Filter 2: latitude check - check for matching latitudes between SHIPS and IBTrACS, length of matching list > 0
            IBTrACS_TC_index_lat = [index for index, item in enumerate(SHIPS_TC['center_lat']) 
                                    if SHIPS_TC['time'].iloc[index] in IBTrACS_TC.time]
            # Filter 3: longitude check - check for matching longitude between SHIPS and IBTrACS, length of matching list > 0
            # However, here we grab indices for where the matches occur. 
            # These indices will be used to assign shear values to the iterand timestamps in IBTrACS
            IBTrACS_TC_index_lons = []
            # Iterate over all longitudes in the iterand TC
            for index, item in enumerate(SHIPS_TC['center_lon']):
                # Get the index of the SHIPS timestamp that matches the IBTrACS timestamp
                if SHIPS_TC['time'].iloc[index] in IBTrACS_TC.time:
                    # Only get indices of IBTrACS timestamps that are in SHIPS
                    valid_indices = np.where(IBTrACS_TC.time.values == SHIPS_TC['time'].iloc[index])
                    if len(valid_indices) > 0: IBTrACS_TC_index_lons.append(valid_indices[0])
            # Flatten indices into a single list
            IBTrACS_TC_index_lons = np.concatenate(IBTrACS_TC_index_lons).ravel()

            # Check if filters apply
            if len(IBTrACS_TC_index_lat) > 0 and len(IBTrACS_TC_index_lons) > 0:
                arr_TMP = np.full(len(IBTrACS_TC['wmo_wind']), np.nan)
                # Ensure that SHIPS shear values and number of matching indices are the same
                if len(IBTrACS_TC_index_lons) == len(SHIPS_TC['SHRD']):
                    
                    arr_TMP[IBTrACS_TC_index_lons] = SHIPS_TC['SHRD']
                    IBTrACS_TC['shear-200_850'] = IBTrACS_TC['wmo_wind']
                    if diagnostic: print(f'Length of IBTrACS data: {len(IBTrACS_TC['shear-200_850'].data)}')
                    # Assign the data to the dataset
                    IBTrACS_TC['shear-200_850'].data = arr_TMP

                    # Apply padding with nans along the `date_time` axis to maintain congruence for concatenation
                    IBTrACS_TC = IBTrACS_TC.pad(date_time=(0, original_axis_length - len(IBTrACS_TC['date_time'])))
                    
                    IBTrACS_TCs.append(IBTrACS_TC)
                else:
                    print('Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.')
                    continue

    return IBTrACS_TCs

# %% [markdown]
# #### Step 1: load SHIPS data, perform corrections, and load IBTrACS data into memory

# %%
# Load SHIPS data
data = load_SHIPS()
# Perform data cleaning and conversions
data = adjust_SHIPS(data)
# Load IBTrACS data into memory for faster processing
TRACS = xr.open_dataset('/scratch/gpfs/GEOCLIM/gr7610/tiger3/reference/datasets/IBTrACS/IBTrACS.since1980.v04r01.nc').load()

# %% [markdown]
# #### Step 2. process SHIPS data by integrating it with IBTrACS data

# %%
# Initialize a container for all TCs
TMP_TCs = []

# Iterate over all TCs
for storm_number, storm_id in enumerate(data['storm_id'].unique()):
    
    start_time = time.time()
    TMP_TC = merge_IBTrACS_SHIPS_TC(SHIPS_TC=data.loc[data['storm_id'] == storm_id], 
                                    dataset_IBTrACS=TRACS, 
                                    diagnostic=False)
    print(f'Elapsed time for storm {storm_id}: {(time.time() - start_time):.2f} s')

    # Only append if the function yields a non-empty dataset
    if len(TMP_TC) > 0: TMP_TCs.append(TMP_TC[0])

    # if storm_number > 5: break

# Get number of TCs processed
unique_TCs = len([item for item in TMP_TCs if len(item) > 0])
# Out:
# Elapsed time for storm AL011982: 1.12 s
# Elapsed time for storm AL031982: 0.91 s
# Elapsed time for storm AL051982: 0.91 s
# Elapsed time for storm AL061982: 0.88 s
# Elapsed time for storm AL081982: 0.90 s
# Elapsed time for storm AL031983: 0.76 s
# Elapsed time for storm AL041983: 0.77 s
# Elapsed time for storm AL051983: 0.78 s
# Elapsed time for storm AL061983: 0.79 s
# Elapsed time for storm AL061984: 0.90 s
# Elapsed time for storm AL071984: 0.91 s
# Elapsed time for storm AL081984: 0.93 s
# Elapsed time for storm AL101984: 0.90 s
# Elapsed time for storm AL111984: 0.91 s
# Elapsed time for storm AL121984: 0.93 s
# Elapsed time for storm AL131984: 0.90 s
# Elapsed time for storm AL141984: 0.89 s
# Elapsed time for storm AL151984: 0.90 s
# Elapsed time for storm AL161984: 0.90 s
# Elapsed time for storm AL181984: 0.90 s
# Elapsed time for storm AL201984: 0.91 s
# Elapsed time for storm AL011985: 0.94 s
# Elapsed time for storm AL021985: 1.01 s
# Elapsed time for storm AL031985: 0.94 s
# Elapsed time for storm AL041985: 0.93 s
# Elapsed time for storm AL051985: 0.96 s
# Elapsed time for storm AL081985: 0.94 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL091985: 0.93 s
# Elapsed time for storm AL101985: 0.94 s
# Elapsed time for storm AL111985: 0.95 s
# Elapsed time for storm AL121985: 0.95 s
# Elapsed time for storm AL131985: 0.96 s
# Elapsed time for storm AL011986: 0.83 s
# Elapsed time for storm AL021986: 0.82 s
# Elapsed time for storm AL051986: 0.84 s
# Elapsed time for storm AL081986: 0.83 s
# Elapsed time for storm AL091986: 0.84 s
# Elapsed time for storm AL101986: 0.85 s
# Elapsed time for storm AL021987: 0.80 s
# Elapsed time for storm AL051987: 0.81 s
# Elapsed time for storm AL071987: 0.82 s
# Elapsed time for storm AL101987: 0.80 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL121987: 0.80 s
# Elapsed time for storm AL131987: 0.82 s
# Elapsed time for storm AL011988: 0.87 s
# Elapsed time for storm AL021988: 0.84 s
# Elapsed time for storm AL031988: 0.83 s
# Elapsed time for storm AL041988: 0.83 s
# Elapsed time for storm AL051988: 0.86 s
# Elapsed time for storm AL071988: 0.90 s
# Elapsed time for storm AL081988: 0.84 s
# Elapsed time for storm AL091988: 0.83 s
# Elapsed time for storm AL101988: 0.84 s
# Elapsed time for storm AL111988: 0.83 s
# Elapsed time for storm AL121988: 0.84 s
# Elapsed time for storm AL011989: 0.91 s
# Elapsed time for storm AL021989: 0.90 s
# Elapsed time for storm AL031989: 0.93 s
# Elapsed time for storm AL041989: 0.94 s
# Elapsed time for storm AL051989: 0.93 s
# Elapsed time for storm AL061989: 0.92 s
# Elapsed time for storm AL071989: 0.92 s
# Elapsed time for storm AL081989: 0.92 s
# Elapsed time for storm AL091989: 0.95 s
# Elapsed time for storm AL101989: 0.92 s
# Elapsed time for storm AL111989: 0.92 s
# Elapsed time for storm AL121989: 0.93 s
# Elapsed time for storm AL131989: 0.95 s
# Elapsed time for storm AL141989: 0.92 s
# Elapsed time for storm AL151989: 0.94 s
# Elapsed time for storm AL011990: 0.88 s
# Elapsed time for storm AL021990: 0.90 s
# Elapsed time for storm AL031990: 0.89 s
# Elapsed time for storm AL041990: 0.90 s
# Elapsed time for storm AL061990: 0.87 s
# Elapsed time for storm AL051990: 0.91 s
# Elapsed time for storm AL071990: 0.96 s
# Elapsed time for storm AL081990: 0.89 s
# Elapsed time for storm AL091990: 0.90 s
# Elapsed time for storm AL101990: 0.88 s
# Elapsed time for storm AL111990: 0.90 s
# Elapsed time for storm AL121990: 0.88 s
# Elapsed time for storm AL131990: 0.89 s
# Elapsed time for storm AL141990: 0.89 s
# Elapsed time for storm AL151990: 0.90 s
# Elapsed time for storm AL161990: 0.91 s
# Elapsed time for storm AL011991: 0.73 s
# Elapsed time for storm AL021991: 0.72 s
# Elapsed time for storm AL031991: 0.74 s
# Elapsed time for storm AL041991: 0.75 s
# Elapsed time for storm AL051991: 0.74 s
# Elapsed time for storm AL061991: 0.74 s
# Elapsed time for storm AL071991: 0.74 s
# Elapsed time for storm AL081991: 0.77 s
# Elapsed time for storm AL091991: 0.74 s
# Elapsed time for storm AL101991: 0.75 s
# Elapsed time for storm AL111991: 0.76 s
# Elapsed time for storm AL121991: 0.76 s
# Elapsed time for storm AL011992: 0.91 s
# Elapsed time for storm AL021992: 0.94 s
# Elapsed time for storm AL031992: 0.92 s
# Elapsed time for storm AL041992: 0.91 s
# Elapsed time for storm AL051992: 0.94 s
# Elapsed time for storm AL061992: 0.96 s
# Elapsed time for storm AL071992: 1.03 s
# Elapsed time for storm AL081992: 0.95 s
# Elapsed time for storm AL091992: 0.93 s
# Elapsed time for storm AL101992: 0.94 s
# Elapsed time for storm AL011993: 0.77 s
# Elapsed time for storm AL021993: 0.77 s
# Elapsed time for storm AL031993: 0.79 s
# Elapsed time for storm AL041993: 0.79 s
# Elapsed time for storm AL051993: 0.78 s
# Elapsed time for storm AL061993: 0.81 s
# Elapsed time for storm AL071993: 0.80 s
# Elapsed time for storm AL081993: 0.77 s
# Elapsed time for storm AL091993: 0.80 s
# Elapsed time for storm AL101993: 0.79 s
# Elapsed time for storm AL011994: 0.84 s
# Elapsed time for storm AL021994: 0.87 s
# Elapsed time for storm AL031994: 0.86 s
# Elapsed time for storm AL041994: 0.87 s
# Elapsed time for storm AL051994: 0.86 s
# Elapsed time for storm AL061994: 0.87 s
# Elapsed time for storm AL071994: 0.86 s
# Elapsed time for storm AL081994: 0.89 s
# Elapsed time for storm AL091994: 0.88 s
# Elapsed time for storm AL101994: 0.85 s
# Elapsed time for storm AL111994: 0.85 s
# Elapsed time for storm AL121994: 0.85 s
# Elapsed time for storm AL011995: 0.75 s
# Elapsed time for storm AL021995: 0.82 s
# Elapsed time for storm AL031995: 0.75 s
# Elapsed time for storm AL041995: 0.75 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL051995: 0.74 s
# Elapsed time for storm AL061995: 0.75 s
# Elapsed time for storm AL071995: 0.74 s
# Elapsed time for storm AL081995: 0.77 s
# Elapsed time for storm AL091995: 0.74 s
# Elapsed time for storm AL101995: 0.76 s
# Elapsed time for storm AL111995: 0.78 s
# Elapsed time for storm AL121995: 0.76 s
# Elapsed time for storm AL131995: 0.75 s
# Elapsed time for storm AL141995: 0.76 s
# Elapsed time for storm AL151995: 0.76 s
# Elapsed time for storm AL161995: 0.75 s
# Elapsed time for storm AL171995: 0.77 s
# Elapsed time for storm AL181995: 0.76 s
# Elapsed time for storm AL191995: 0.75 s
# Elapsed time for storm AL201995: 0.78 s
# Elapsed time for storm AL211995: 0.77 s
# Elapsed time for storm AL011996: 0.85 s
# Elapsed time for storm AL021996: 0.84 s
# Elapsed time for storm AL031996: 0.86 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL041996: 0.85 s
# Elapsed time for storm AL051996: 0.87 s
# Elapsed time for storm AL061996: 0.84 s
# Elapsed time for storm AL071996: 0.88 s
# Elapsed time for storm AL081996: 0.84 s
# Elapsed time for storm AL091996: 0.88 s
# Elapsed time for storm AL101996: 0.85 s
# Elapsed time for storm AL111996: 0.92 s
# Elapsed time for storm AL121996: 0.87 s
# Elapsed time for storm AL131996: 0.85 s
# Elapsed time for storm AL011997: 0.84 s
# Elapsed time for storm AL021997: 0.84 s
# Elapsed time for storm AL031997: 0.82 s
# Elapsed time for storm AL041997: 0.83 s
# Elapsed time for storm AL051997: 0.84 s
# Elapsed time for storm AL061997: 0.84 s
# Elapsed time for storm AL071997: 0.84 s
# Elapsed time for storm AL081997: 0.84 s
# Elapsed time for storm AL091997: 0.85 s
# Elapsed time for storm AL011998: 0.79 s
# Elapsed time for storm AL021998: 0.82 s
# Elapsed time for storm AL031998: 0.82 s
# Elapsed time for storm AL041998: 0.84 s
# Elapsed time for storm AL051998: 0.94 s
# Elapsed time for storm AL061998: 0.87 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL071998: 0.90 s
# Elapsed time for storm AL081998: 0.87 s
# Elapsed time for storm AL091998: 0.87 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL101998: 0.88 s
# Elapsed time for storm AL111998: 0.87 s
# Elapsed time for storm AL121998: 0.86 s
# Elapsed time for storm AL131998: 0.87 s
# Elapsed time for storm AL141998: 0.83 s
# Elapsed time for storm AL011999: 0.86 s
# Elapsed time for storm AL021999: 0.86 s
# Elapsed time for storm AL031999: 0.88 s
# Elapsed time for storm AL041999: 0.84 s
# Elapsed time for storm AL051999: 0.86 s
# Elapsed time for storm AL061999: 0.88 s
# Elapsed time for storm AL071999: 0.89 s
# Elapsed time for storm AL081999: 0.91 s
# Elapsed time for storm AL091999: 0.85 s
# Elapsed time for storm AL101999: 0.88 s
# Elapsed time for storm AL111999: 0.86 s
# Elapsed time for storm AL121999: 0.87 s
# Elapsed time for storm AL131999: 0.86 s
# Elapsed time for storm AL141999: 0.84 s
# Elapsed time for storm AL151999: 0.87 s
# Elapsed time for storm AL161999: 0.85 s
# Elapsed time for storm AL012000: 0.83 s
# Elapsed time for storm AL022000: 0.85 s
# Elapsed time for storm AL032000: 0.84 s
# Elapsed time for storm AL042000: 0.85 s
# Elapsed time for storm AL052000: 0.85 s
# Elapsed time for storm AL062000: 0.86 s
# Elapsed time for storm AL072000: 0.86 s
# Elapsed time for storm AL082000: 0.85 s
# Elapsed time for storm AL092000: 0.87 s
# Elapsed time for storm AL102000: 0.85 s
# Elapsed time for storm AL112000: 0.86 s
# Elapsed time for storm AL122000: 0.83 s
# Elapsed time for storm AL132000: 0.82 s
# Elapsed time for storm AL142000: 0.84 s
# Elapsed time for storm AL152000: 0.83 s
# Elapsed time for storm AL162000: 0.84 s
# Elapsed time for storm AL172000: 0.83 s
# Elapsed time for storm AL182000: 0.83 s
# Elapsed time for storm AL192000: 0.88 s
# Elapsed time for storm AL012001: 0.76 s
# Elapsed time for storm AL022001: 0.78 s
# Elapsed time for storm AL032001: 0.78 s
# Elapsed time for storm AL042001: 0.78 s
# Elapsed time for storm AL052001: 0.84 s
# Elapsed time for storm AL062001: 0.77 s
# Elapsed time for storm AL072001: 0.79 s
# Elapsed time for storm AL082001: 0.80 s
# Elapsed time for storm AL092001: 0.81 s
# Elapsed time for storm AL102001: 0.80 s
# Elapsed time for storm AL112001: 0.79 s
# Elapsed time for storm AL122001: 0.79 s
# Elapsed time for storm AL132001: 0.81 s
# Elapsed time for storm AL142001: 0.79 s
# Elapsed time for storm AL152001: 0.79 s
# Elapsed time for storm AL162001: 0.78 s
# Elapsed time for storm AL172001: 0.78 s
# Elapsed time for storm AL012002: 0.79 s
# Elapsed time for storm AL022002: 0.77 s
# Elapsed time for storm AL032002: 0.78 s
# Elapsed time for storm AL042002: 0.79 s
# Elapsed time for storm AL052002: 0.79 s
# Elapsed time for storm AL062002: 0.79 s
# Elapsed time for storm AL072002: 0.80 s
# Elapsed time for storm AL082002: 0.77 s
# Elapsed time for storm AL092002: 0.79 s
# Elapsed time for storm AL102002: 0.79 s
# Elapsed time for storm AL112002: 0.78 s
# Elapsed time for storm AL122002: 0.78 s
# Elapsed time for storm AL132002: 0.78 s
# Elapsed time for storm AL142002: 0.77 s
# Elapsed time for storm AL012003: 0.79 s
# Elapsed time for storm AL022003: 0.79 s
# Elapsed time for storm AL032003: 0.79 s
# Elapsed time for storm AL042003: 0.79 s
# Elapsed time for storm AL052003: 0.80 s
# Elapsed time for storm AL062003: 0.81 s
# Elapsed time for storm AL072003: 0.80 s
# Elapsed time for storm AL082003: 0.89 s
# Elapsed time for storm AL092003: 0.80 s
# Elapsed time for storm AL102003: 0.80 s
# Elapsed time for storm AL112003: 0.83 s
# Elapsed time for storm AL122003: 0.82 s
# Elapsed time for storm AL132003: 0.81 s
# Elapsed time for storm AL142003: 0.81 s
# Elapsed time for storm AL152003: 0.80 s
# Elapsed time for storm AL162003: 0.79 s
# Elapsed time for storm AL172003: 0.81 s
# Elapsed time for storm AL182003: 0.80 s
# Elapsed time for storm AL192003: 0.79 s
# Elapsed time for storm AL202003: 0.82 s
# Elapsed time for storm AL212003: 0.81 s
# Elapsed time for storm AL012004: 0.77 s
# Elapsed time for storm AL022004: 0.77 s
# Elapsed time for storm AL032004: 0.78 s
# Elapsed time for storm AL042004: 0.77 s
# Elapsed time for storm AL052004: 0.78 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL062004: 0.77 s
# Elapsed time for storm AL072004: 0.81 s
# Elapsed time for storm AL082004: 0.81 s
# Elapsed time for storm AL092004: 0.80 s
# Elapsed time for storm AL102004: 0.82 s
# Elapsed time for storm AL112004: 0.80 s
# Elapsed time for storm AL122004: 0.79 s
# Elapsed time for storm AL132004: 0.80 s
# Elapsed time for storm AL142004: 0.79 s
# Elapsed time for storm AL152004: 0.79 s
# Elapsed time for storm AL162004: 0.81 s
# Elapsed time for storm AL012005: 0.87 s
# Elapsed time for storm AL022005: 0.89 s
# Elapsed time for storm AL032005: 0.89 s
# Elapsed time for storm AL042005: 0.87 s
# Elapsed time for storm AL052005: 0.90 s
# Elapsed time for storm AL062005: 0.90 s
# Elapsed time for storm AL072005: 0.98 s
# Elapsed time for storm AL082005: 0.89 s
# Elapsed time for storm AL092005: 0.89 s
# Elapsed time for storm AL102005: 0.92 s
# Elapsed time for storm AL112005: 0.90 s
# Elapsed time for storm AL122005: 0.90 s
# Elapsed time for storm AL132005: 0.92 s
# Elapsed time for storm AL142005: 0.89 s
# Elapsed time for storm AL152005: 0.92 s
# Elapsed time for storm AL162005: 0.90 s
# Elapsed time for storm AL172005: 0.91 s
# Elapsed time for storm AL182005: 0.91 s
# Elapsed time for storm AL192005: 0.90 s
# Elapsed time for storm AL202005: 0.90 s
# Elapsed time for storm AL212005: 0.91 s
# Elapsed time for storm AL222005: 0.88 s
# Elapsed time for storm AL232005: 0.91 s
# Elapsed time for storm AL242005: 0.90 s
# Elapsed time for storm AL252005: 0.91 s
# Elapsed time for storm AL262005: 0.91 s
# Elapsed time for storm AL272005: 0.89 s
# Elapsed time for storm AL282005: 0.90 s
# Elapsed time for storm AL292005: 0.89 s
# Elapsed time for storm AL302005: 0.91 s
# Elapsed time for storm AL312005: 0.90 s
# Elapsed time for storm AL012006: 0.76 s
# Elapsed time for storm AL022006: 0.77 s
# Elapsed time for storm AL032006: 0.78 s
# Elapsed time for storm AL042006: 0.78 s
# Elapsed time for storm AL052006: 0.78 s
# Elapsed time for storm AL062006: 0.77 s
# Elapsed time for storm AL072006: 0.78 s
# Elapsed time for storm AL082006: 0.76 s
# Elapsed time for storm AL092006: 0.78 s
# Elapsed time for storm AL102006: 0.76 s
# Elapsed time for storm AL012007: 0.81 s
# Elapsed time for storm AL022007: 0.73 s
# Elapsed time for storm AL032007: 0.72 s
# Elapsed time for storm AL042007: 0.73 s
# Elapsed time for storm AL052007: 0.73 s
# Elapsed time for storm AL062007: 0.74 s
# Elapsed time for storm AL072007: 0.73 s
# Elapsed time for storm AL082007: 0.74 s
# Elapsed time for storm AL092007: 0.73 s
# Elapsed time for storm AL102007: 0.75 s
# Elapsed time for storm AL112007: 0.75 s
# Elapsed time for storm AL122007: 0.73 s
# Elapsed time for storm AL132007: 0.74 s
# Elapsed time for storm AL142007: 0.72 s
# Elapsed time for storm AL152007: 0.74 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL162007: 0.73 s
# Elapsed time for storm AL172007: 0.73 s
# Elapsed time for storm AL012008: 0.79 s
# Elapsed time for storm AL022008: 0.78 s
# Elapsed time for storm AL032008: 0.80 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL042008: 0.79 s
# Elapsed time for storm AL052008: 0.80 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL062008: 0.80 s
# Elapsed time for storm AL072008: 0.80 s
# Elapsed time for storm AL082008: 0.80 s
# Elapsed time for storm AL092008: 0.80 s
# Elapsed time for storm AL102008: 0.81 s
# Elapsed time for storm AL112008: 0.81 s
# Elapsed time for storm AL122008: 0.81 s
# Elapsed time for storm AL132008: 0.83 s
# Elapsed time for storm AL142008: 0.83 s
# Elapsed time for storm AL152008: 1.01 s
# Elapsed time for storm AL162008: 1.06 s
# Elapsed time for storm AL172008: 1.01 s
# Elapsed time for storm AL012009: 0.97 s
# Elapsed time for storm AL022009: 0.99 s
# Elapsed time for storm AL032009: 0.97 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL042009: 1.00 s
# Elapsed time for storm AL052009: 1.08 s
# Elapsed time for storm AL062009: 1.25 s
# Elapsed time for storm AL072009: 1.15 s
# Elapsed time for storm AL082009: 1.20 s
# Elapsed time for storm AL092009: 1.40 s
# Elapsed time for storm AL102009: 1.19 s
# Elapsed time for storm AL112009: 1.22 s
# Elapsed time for storm AL012010: 0.71 s
# Elapsed time for storm AL022010: 0.70 s
# Elapsed time for storm AL032010: 0.70 s
# Elapsed time for storm AL042010: 0.71 s
# Elapsed time for storm AL052010: 0.71 s
# Elapsed time for storm AL062010: 0.70 s
# Elapsed time for storm AL072010: 0.71 s
# Elapsed time for storm AL082010: 0.73 s
# Elapsed time for storm AL092010: 0.74 s
# Elapsed time for storm AL102010: 0.71 s
# Elapsed time for storm AL112010: 0.71 s
# Elapsed time for storm AL122010: 0.72 s
# Elapsed time for storm AL132010: 0.72 s
# Elapsed time for storm AL142010: 0.73 s
# Elapsed time for storm AL152010: 0.72 s
# Elapsed time for storm AL162010: 0.71 s
# Elapsed time for storm AL172010: 0.73 s
# Elapsed time for storm AL182010: 0.71 s
# Elapsed time for storm AL192010: 0.74 s
# Elapsed time for storm AL202010: 0.72 s
# Elapsed time for storm AL212010: 0.71 s
# Elapsed time for storm AL012011: 0.74 s
# Elapsed time for storm AL022011: 0.77 s
# Elapsed time for storm AL032011: 0.76 s
# Elapsed time for storm AL042011: 0.76 s
# Elapsed time for storm AL052011: 0.77 s
# Elapsed time for storm AL062011: 0.76 s
# Elapsed time for storm AL072011: 0.74 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL082011: 0.77 s
# Elapsed time for storm AL092011: 0.75 s
# Elapsed time for storm AL102011: 0.77 s
# Elapsed time for storm AL112011: 0.77 s
# Elapsed time for storm AL122011: 0.75 s
# Elapsed time for storm AL202011: 0.83 s
# Elapsed time for storm AL132011: 0.78 s
# Elapsed time for storm AL142011: 0.75 s
# Elapsed time for storm AL152011: 0.77 s
# Elapsed time for storm AL162011: 0.75 s
# Elapsed time for storm AL172011: 0.77 s
# Elapsed time for storm AL182011: 0.76 s
# Elapsed time for storm AL192011: 0.75 s
# Elapsed time for storm AL012012: 0.72 s
# Elapsed time for storm AL022012: 0.73 s
# Elapsed time for storm AL032012: 0.72 s
# Elapsed time for storm AL042012: 0.72 s
# Elapsed time for storm AL052012: 0.74 s
# Elapsed time for storm AL062012: 0.76 s
# Elapsed time for storm AL072012: 0.72 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL082012: 0.72 s
# Elapsed time for storm AL092012: 0.75 s
# Elapsed time for storm AL102012: 0.75 s
# Elapsed time for storm AL112012: 0.74 s
# Elapsed time for storm AL122012: 0.73 s
# Elapsed time for storm AL132012: 0.74 s
# Elapsed time for storm AL142012: 0.73 s
# Elapsed time for storm AL152012: 0.75 s
# Elapsed time for storm AL162012: 0.74 s
# Elapsed time for storm AL172012: 0.76 s
# Elapsed time for storm AL182012: 0.74 s
# Elapsed time for storm AL192012: 0.76 s
# Elapsed time for storm AL012013: 0.79 s
# Elapsed time for storm AL022013: 0.79 s
# Elapsed time for storm AL032013: 0.79 s
# Elapsed time for storm AL042013: 0.78 s
# Elapsed time for storm AL052013: 0.82 s
# Elapsed time for storm AL062013: 0.81 s
# Elapsed time for storm AL072013: 0.79 s
# Elapsed time for storm AL082013: 0.80 s
# Elapsed time for storm AL092013: 0.78 s
# Elapsed time for storm AL102013: 0.80 s
# Elapsed time for storm AL112013: 0.79 s
# Elapsed time for storm AL122013: 0.82 s
# Elapsed time for storm AL132013: 0.81 s
# Elapsed time for storm AL142013: 0.91 s
# Elapsed time for storm AL152013: 0.82 s
# Elapsed time for storm AL012014: 0.72 s
# Elapsed time for storm AL022014: 0.72 s
# Elapsed time for storm AL032014: 0.74 s
# Elapsed time for storm AL042014: 0.74 s
# Elapsed time for storm AL052014: 0.72 s
# Elapsed time for storm AL062014: 0.72 s
# Elapsed time for storm AL072014: 0.74 s
# Elapsed time for storm AL082014: 0.74 s
# Elapsed time for storm AL092014: 0.73 s
# Elapsed time for storm AL012015: 0.84 s
# Elapsed time for storm AL022015: 0.82 s
# Elapsed time for storm AL032015: 0.85 s
# Elapsed time for storm AL042015: 0.85 s
# Elapsed time for storm AL052015: 0.85 s
# Elapsed time for storm AL062015: 0.85 s
# Elapsed time for storm AL072015: 0.85 s
# Elapsed time for storm AL082015: 0.85 s
# Elapsed time for storm AL092015: 0.84 s
# Elapsed time for storm AL102015: 0.84 s
# Elapsed time for storm AL112015: 0.83 s
# Elapsed time for storm AL122015: 0.83 s
# Elapsed time for storm AL012016: 0.76 s
# Elapsed time for storm AL022016: 0.77 s
# Elapsed time for storm AL032016: 0.75 s
# Elapsed time for storm AL042016: 0.75 s
# Elapsed time for storm AL052016: 0.77 s
# Elapsed time for storm AL062016: 0.79 s
# Elapsed time for storm AL072016: 0.77 s
# Elapsed time for storm AL082016: 0.78 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL092016: 0.78 s
# Elapsed time for storm AL102016: 0.79 s
# Elapsed time for storm AL112016: 0.79 s
# Elapsed time for storm AL122016: 0.77 s
# Elapsed time for storm AL132016: 0.77 s
# Elapsed time for storm AL142016: 0.78 s
# Elapsed time for storm AL152016: 0.79 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL162016: 0.87 s
# Elapsed time for storm AL012017: 0.81 s
# Elapsed time for storm AL022017: 0.82 s
# Elapsed time for storm AL032017: 0.83 s
# Elapsed time for storm AL042017: 0.82 s
# Elapsed time for storm AL052017: 0.83 s
# Elapsed time for storm AL062017: 0.84 s
# Elapsed time for storm AL072017: 0.83 s
# Elapsed time for storm AL082017: 0.82 s
# Elapsed time for storm AL092017: 0.82 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL112017: 0.81 s
# Elapsed time for storm AL122017: 0.83 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL132017: 0.82 s
# Elapsed time for storm AL142017: 0.82 s
# Elapsed time for storm AL152017: 0.82 s
# Elapsed time for storm AL162017: 0.83 s
# Elapsed time for storm AL172017: 0.81 s
# Elapsed time for storm AL182017: 0.83 s
# Elapsed time for storm AL192017: 0.82 s
# Elapsed time for storm AL012018: 0.85 s
# Elapsed time for storm AL022018: 0.84 s
# Elapsed time for storm AL032018: 0.85 s
# Elapsed time for storm AL042018: 0.88 s
# Elapsed time for storm AL052018: 0.89 s
# Elapsed time for storm AL062018: 0.85 s
# Elapsed time for storm AL072018: 0.88 s
# Elapsed time for storm AL082018: 0.87 s
# Elapsed time for storm AL092018: 0.88 s
# Elapsed time for storm AL102018: 0.85 s
# Elapsed time for storm AL112018: 0.86 s
# Elapsed time for storm AL122018: 0.88 s
# Elapsed time for storm AL132018: 0.86 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL142018: 0.88 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL152018: 0.90 s
# Elapsed time for storm AL162018: 0.87 s
# Elapsed time for storm AL012019: 0.86 s
# Elapsed time for storm AL022019: 0.84 s
# Elapsed time for storm AL032019: 0.85 s
# Elapsed time for storm AL042019: 0.85 s
# Elapsed time for storm AL052019: 0.85 s
# Elapsed time for storm AL062019: 0.87 s
# Elapsed time for storm AL072019: 1.02 s
# Elapsed time for storm AL082019: 0.87 s
# Elapsed time for storm AL092019: 0.86 s
# Elapsed time for storm AL102019: 0.89 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL112019: 0.89 s
# Elapsed time for storm AL122019: 0.86 s
# Elapsed time for storm AL132019: 0.85 s
# Elapsed time for storm AL142019: 0.86 s
# Elapsed time for storm AL152019: 0.87 s
# Elapsed time for storm AL162019: 0.88 s
# Elapsed time for storm AL172019: 0.87 s
# Elapsed time for storm AL182019: 0.87 s
# Elapsed time for storm AL192019: 0.89 s
# Elapsed time for storm AL202019: 0.88 s
# Elapsed time for storm AL012020: 0.87 s
# Elapsed time for storm AL022020: 0.86 s
# Elapsed time for storm AL032020: 0.86 s
# Elapsed time for storm AL042020: 0.88 s
# Elapsed time for storm AL052020: 0.87 s
# Elapsed time for storm AL062020: 0.87 s
# Elapsed time for storm AL072020: 0.87 s
# Elapsed time for storm AL082020: 0.88 s
# Elapsed time for storm AL092020: 0.88 s
# Elapsed time for storm AL102020: 0.90 s
# Elapsed time for storm AL112020: 0.87 s
# Elapsed time for storm AL122020: 0.88 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL132020: 0.88 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL142020: 0.88 s
# Elapsed time for storm AL152020: 0.89 s
# Elapsed time for storm AL162020: 0.90 s
# Elapsed time for storm AL172020: 0.88 s
# Elapsed time for storm AL182020: 0.90 s
# Elapsed time for storm AL192020: 0.88 s
# Elapsed time for storm AL202020: 0.89 s
# Elapsed time for storm AL212020: 0.92 s
# Elapsed time for storm AL222020: 0.92 s
# Elapsed time for storm AL232020: 0.90 s
# Elapsed time for storm AL242020: 0.92 s
# Elapsed time for storm AL252020: 0.89 s
# Elapsed time for storm AL262020: 0.99 s
# Elapsed time for storm AL272020: 0.89 s
# Elapsed time for storm AL282020: 0.89 s
# Elapsed time for storm AL292020: 0.89 s
# Elapsed time for storm AL302020: 0.90 s
# Elapsed time for storm AL312020: 0.90 s
# Elapsed time for storm AL012021: 0.84 s
# Elapsed time for storm AL022021: 0.85 s
# Elapsed time for storm AL032021: 0.83 s
# Elapsed time for storm AL042021: 0.85 s
# Elapsed time for storm AL052021: 0.84 s
# Elapsed time for storm AL062021: 0.86 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL072021: 0.85 s
# Elapsed time for storm AL082021: 0.87 s
# Elapsed time for storm AL092021: 0.84 s
# Elapsed time for storm AL102021: 0.85 s
# Elapsed time for storm AL112021: 0.87 s
# Elapsed time for storm AL122021: 0.84 s
# Elapsed time for storm AL132021: 0.87 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL142021: 0.85 s
# Elapsed time for storm AL152021: 0.85 s
# Elapsed time for storm AL162021: 0.86 s
# Elapsed time for storm AL172021: 0.86 s
# Elapsed time for storm AL182021: 0.86 s
# Elapsed time for storm AL192021: 0.89 s
# Elapsed time for storm AL202021: 0.87 s
# Elapsed time for storm AL212021: 0.86 s
# Elapsed time for storm AL012022: 0.84 s
# Elapsed time for storm AL022022: 0.86 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL032022: 0.85 s
# Elapsed time for storm AL052022: 0.85 s
# Elapsed time for storm AL062022: 0.85 s
# Elapsed time for storm AL072022: 0.86 s
# Elapsed time for storm AL082022: 0.87 s
# Length of SHIPS shear values and matching IBTrACS-SHIPS coordinates is not equal.
# Elapsed time for storm AL092022: 0.84 s
# Elapsed time for storm AL102022: 0.89 s
# Elapsed time for storm AL112022: 0.88 s
# Elapsed time for storm AL122022: 0.86 s
# Elapsed time for storm AL132022: 0.86 s
# Elapsed time for storm AL142022: 0.86 s
# Elapsed time for storm AL152022: 0.86 s
# Elapsed time for storm AL162022: 0.97 s
# Elapsed time for storm AL172022: 0.87 s

# %% [markdown]
# #### Step 3. concatenate and save data

# %%
TMP_TCs = xr.concat(TMP_TCs, dim='storm')

storage_dirname = '/scratch/gpfs/GEOCLIM/gr7610/tiger3/reference/datasets/IBTrACS'
storage_filename = 'IBTrACS.since1980.v04r01.SHIPS.basin-NA.nc'
TMP_TCs.to_netcdf(os.path.join(storage_dirname, storage_filename))
