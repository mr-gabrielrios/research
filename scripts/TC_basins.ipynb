# %%
import cartopy, cartopy.crs as ccrs, matplotlib, matplotlib.pyplot as plt

import visualization

# %%
visualization.basins(visualize=True)
# Out:
# {'NI': [40, 100, 0, 30],
#  'SI': [40, 120, -40, 0],
#  'WP': [100, 180, 0, 40],
#  'SP': [120, 260, -40, 0],
#  'EP': [180, 260, 0, 40],
#  'NA': [260, 360, 0, 40],
#  'SA': [300, 360, -40, 0]}
